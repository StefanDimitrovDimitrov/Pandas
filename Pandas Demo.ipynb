# %%
import pandas as pd

# %%
df = pd.read_csv('developers_survey\srp.csv', index_col='Respondent')
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# 2                     GBP  ...                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# ...

# %%
df.teal(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\STEFAN~1\AppData\Local\Temp/ipykernel_18204/1848450453.py in <module>
# ----> 1 df.teal(3)
#
# d:\forest\github_master\pandas\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'teal'

# %%
df.tail(2)

# %%
clear

# %%
clean

# %%
df.shape

# %%
df.info()

# %%
pd.set_option('display.max_columns', 61)

# %%
df.column()

# %%
df.columns

# %%
df.shape

# %%
df['Hobbyist']

# %%
df['Hobbyist'].value_counts()

# %%
df.iloc[1,2]

# %%
df.loc[:,'Hobbyist'].head(4)

# %%
df.loc[:, 'Hobbyist':'Employment'].head(6)

# %%
df.iloc[:6, 1:5]

# %%
df_schema = pd.read_csv('developers_survey\srs.csv', index_col='Column')

# %%
df_schema

# %%
df_schema.loc['NEWLearn', 'QuestionText']

# %%
df_schema.sort_index()

# %%
high_salary = df['ConvertedComp'] > 7000
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]

# %%
df.loc[~filt, 'Country']

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt

# %%
df.loc[filt]

# %%
df.column

# %%
df.columns

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.columns

# %%
df.columns = [x.lower() for x in df.columns]
df.rename(columns={"convertedcomp":"SalaryUSD"}, inplace=True)

# %%
df

# %%
df['hobbyist'] = df['hobbyist'].map({'Yes': True, 'No': False})

# %%
df

# %%
df.sort_values(by=["country","salaryusd"], ascending=[True,False], inplace=True)

# %%
df[['country', 'salaryusd']].head(60)

# %%
country_respondents = df['country'].value_counts()

# %%
country_respondents

# %%
country_grp = df.groupby(['country'])
country_uses_python = country_grp['languageworkedwith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)

# %%
python_df

# %%
python_df.rename(columns={'country':'NumRespondents', 'languageworkedwith':'NumKnowsPython'}, inplace=True)

# %%
python_df

# %%
python_df['pctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100

# %%
python_df.sort_values(by='pctKnowsPython', ascending=False, inplace=True)

# %%
python_df

# %%
df['yearscode'].unique()

# %%
df['yearscode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['yearscode'].unique()

# %%
df['yearscode'].replace('More than 50 years', 51, inplace=True)

# %%
df['yearscode'].unique()

# %%
df['yearscode'] = df['yearscode'].astype(float)

# %%
df['yearscode'].mean()

# %%
df['yearscode'].median()
